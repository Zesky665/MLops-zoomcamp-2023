# %% [markdown]
# This the homework for week 1 of the MLOps zoomcamp

# %%
# !python -V
# !pip install seaborn
# !pip install scikit-learn
# !pip install pickle
# Out:
# Python 3.8.12
# ...
#
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle
#
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import pyarrow
import pickle
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression, LogisticRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error

# %%
def read_dataframe(path):
    df = pd.read_parquet(path)
    df['duration'] = df.tpep_dropoff_datetime - df.tpep_pickup_datetime
    df['duration'] = df.duration.dt.total_seconds()/60
    categorical = ['PULocationID','DOLocationID']
    
    df[categorical] = df[categorical].astype(str)
    
    return df

# %%
path = 'data/yellow_tripdata_2022-01.parquet'
df = pd.read_parquet(path)
df
# len(df.columns)
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1               1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2               2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3               2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4               2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ...           ...                  ...                   ...              ...
# 2463926         2  2022-01-31 23:36:53   2022-01-31 23:42:51              NaN
# 2463927         2  2022-01-31 23:44:22   2022-01-31 23:55:01              NaN
# 2463928         2  2022-01-31 23:39:00   2022-01-31 23:50:00              NaN
# 2463929         2  2022-01-31 23:36:42   2022-01-31 23:48:45              NaN
# 2463930         2  2022-01-31 23:46:00   2022-02-01 00:13:00              NaN
#
# ...

# %% [markdown]
# Q_1: Read the data for January. How many columns are there?
# Answer: 19

# %%
df_train = read_dataframe('data/yellow_tripdata_2022-01.parquet')
df_val = read_dataframe('data/yellow_tripdata_2022-02.parquet')

# %%
len(df_train), len(df_val)

df_train
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1               1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2               2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3               2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4               2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ...           ...                  ...                   ...              ...
# 2463926         2  2022-01-31 23:36:53   2022-01-31 23:42:51              NaN
# 2463927         2  2022-01-31 23:44:22   2022-01-31 23:55:01              NaN
# 2463928         2  2022-01-31 23:39:00   2022-01-31 23:50:00              NaN
# 2463929         2  2022-01-31 23:36:42   2022-01-31 23:48:45              NaN
# 2463930         2  2022-01-31 23:46:00   2022-02-01 00:13:00              NaN
#
# ...

# %%
dur = df_train['duration']

np.std(dur)
# Out:
# 46.445295712725304

# %% [markdown]
# Q_2: What's the standard deviation of the trips duration in January?
# Answer: 46.45

# %%
before = len(df_train)
df_train = df_train[(df_train.duration > 1) & (df_train.duration <= 60)]
df_val = df_val[(df_val.duration > 1) & (df_val.duration <= 60)]
after = len(df_train)

fraction = after / before

fraction
# Out:
# 0.9826216724413143

# %% [markdown]
# Q_3: What fraction of the records left after you dropped the outliers?
# Answer: 98%

# %%
categorical = ['PULocationID','DOLocationID']
numerical = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
X_train.ndim
# Out:
# <2917848x516 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8753538 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Q_4: What's the dimensionality of this matrix (number of columns)?
# Answer: 2

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_train)

mean_squared_error(y_train, y_pred, squared=False)
# Out:
# 7.000035096658634

# %% [markdown]
# Q_5: What's the RMSE on train?
# Answer: 6.99 or 7.00

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 7.794205733165656

# %% [markdown]
# Q_5: What's the RMSE on train?
# Answer: 7.79
